# %%
import pandas as pd
import matplotlib.ticker as tk

# %%
df = pd.read_json('blocks.json')

# %%
ax = df.plot.line(x='block', y='baseFeePerGas', figsize=(18, 12), title="Sevens Mint Base Fee Escalation")
ax.set_xlabel("Block Number", fontsize=13)
ax.set_ylabel("Base Fee Per Gas", fontsize=13)
# Out:
# Text(0, 0.5, 'Base Fee Per Gas')

# %%
ax.get_figure().savefig('sevens.png')
